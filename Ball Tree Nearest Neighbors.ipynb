# %% [markdown]
# # Finding the two closest Torchy's Tacos Locations
#
# In this notebook, I will use the coordinates calculated through the previous example to find the two nearest Torchy's Tacos Locations to the apartments on the list. I gathered the locations of each Torchy's Tacos in Houston from their website.
#
# I used a Ball Tree to calculate distances based on radial distances to the center. This calculates the Haversine distance between two points using the scikit-learn library.
#
# I used [this tutorial](https://towardsdatascience.com/using-scikit-learns-binary-trees-to-efficiently-find-latitude-and-longitude-neighbors-909979bd929b) to calculate the distances between two points and to find the K-Nearest Torchy's.

# %%
#Load libraries
import pandas as pd
from sklearn.neighbors import BallTree
import numpy as np

# %%
#Load Torchy's and Apartment data
tor_df = pd.read_csv('Torchys Locations.csv')
apt_df = pd.read_csv('Houston_Apt_Coordinates.csv')

# %%
tor_df
# Out:
#                                          Address           County     City  \
# 0         2411 S. Shepherd Dr, Houston, TX 77019         Shepherd  Houston
# 1  350 W. 19th Street, Ste. A, Houston, TX 77008  Houston Heights  Houston
# 2            2400 Times Blvd., Houston, TX 77005     Rice Village  Houston
# 3           5537 Weslayan St., Houston, TX 77005           West U  Houston
# 4         5885 San Felipe St., Houston, TX 77057       San Felipe  Houston
# 5   1035 Gessner Rd., Suite A, Houston, TX 77055    Memorial City  Houston
# 6           2675 Wilcrest Dr., Houston, TX 77042        Westchase  Houston
#
#            Lat       Long
# 0   29.7441232 -95.410407
# 1   29.8026671 -95.403260
# 2    29.716962 -95.415129
# 3  29.7217129, -95.440822
# 4   29.7490665 -95.484253
# 5   29.7858622 -95.544912
# 6   29.7352069 -95.571263

# %%
tor_df.dtypes
# Out:
# Address     object
# County      object
# City        object
# Lat        float64
# Long       float64
# dtype: object

# %%
apt_df
# Out:
#      Unnamed: 0                     Apartment  \
# 0             0                  The Augusta
# 1             1      Lanesborough Apartments
# 2             2     Tuscany Court Apartments
# 3             3  The Trails At Dominion Park
# 4             4            5401 Chimney Rock
# ..          ...                           ...
# 103         103                  The Carlton
# 104         104                      Circuit
# 105         105               Avana Eldridge
# 106         106                 Jackson Hill
# 107         107       Veranda at Centerfield
#
#                                   Address  location_lat  location_long  \
# 0            2660 Augusta Dr, Houston, TX     29.739297     -95.482587
# 1        1819 Braeswood Blvd, Houston, TX     29.706742     -95.394089
# 2            1901 Augusta Dr, Houston, TX     29.747442     -95.482511
# 3       200 Dominion Park Dr, Houston, TX     29.975664     -95.424768
# 4       5401 Chimney Rock Rd, Houston, TX     29.723425     -95.475772
# ..                                    ...           ...            ...
# 103        3805 W Alabama St, Houston, TX     29.738168     -95.438803
# 104          2424 Capitol St, Houston, TX     29.751732     -95.350933
# 105       1415 Eldridge Pkwy, Houston, TX     29.758541     -95.625225
# 106      320 Jackson Hill St, Houston, TX     29.764461     -95.401687
# 107   7700 Willow Chase Blvd, Houston, TX     29.966437     -95.547377
#
#                                       location_address
# 0    2660, Augusta Drive, Houston, Harris County, T...
# 1    Braeswood Boulevard, Texas Medical Center, Hou...
# 2    1901, Augusta Drive, Houston, Harris County, T...
# 3    200, Dominion Park Drive, North Houston Distri...
# 4    5401, Chimney Rock Road, Houston, Harris Count...
# ..                                                 ...
# 103  3805, West Alabama Street, Highland Village, H...
# 104  2424, Capitol Street, Houston, Harris County, ...
# 105  1415, Eldridge Parkway, Houston, Harris County...
# 106  320, Jackson Hill Street, Houston, Harris Coun...
# 107  7700, Willow Chase Boulevard, Houston, Harris ...
#
# [108 rows x 6 columns]

# %% [markdown]
# To use the Ball Tree with the Haversine distance, the cartesian coordinates need to be converted from degrees to radians.

# %%
#Using Haversine distance, need to convert coordinates from degrees to radians

for column in tor_df[['Lat', 'Long']]:
    rad = np.deg2rad(tor_df[column].values)
    tor_df[f'{column}_rad'] = rad

for column in apt_df[['location_lat', 'location_long']]:
    rad = np.deg2rad(apt_df[column].values)
    apt_df[f'{column}_rad'] = rad

# %%
tor_df
# Out:
#                                          Address           County     City  \
# 0         2411 S. Shepherd Dr, Houston, TX 77019         Shepherd  Houston
# 1  350 W. 19th Street, Ste. A, Houston, TX 77008  Houston Heights  Houston
# 2            2400 Times Blvd., Houston, TX 77005     Rice Village  Houston
# 3           5537 Weslayan St., Houston, TX 77005           West U  Houston
# 4         5885 San Felipe St., Houston, TX 77057       San Felipe  Houston
# 5   1035 Gessner Rd., Suite A, Houston, TX 77055    Memorial City  Houston
# 6           2675 Wilcrest Dr., Houston, TX 77042        Westchase  Houston
#
#          Lat       Long   Lat_rad  Long_rad
# 0  29.744123 -95.410407  0.519133 -1.665226
# 1  29.802667 -95.403260  0.520155 -1.665101
# 2  29.716962 -95.415129  0.518659 -1.665308
# 3  29.721713 -95.440822  0.518742 -1.665757
# 4  29.749067 -95.484253  0.519219 -1.666515
# 5  29.785862 -95.544912  0.519861 -1.667573
# 6  29.735207 -95.571263  0.518977 -1.668033

# %%
apt_df
# Out:
#      Unnamed: 0                     Apartment  \
# 0             0                  The Augusta
# 1             1      Lanesborough Apartments
# 2             2     Tuscany Court Apartments
# 3             3  The Trails At Dominion Park
# 4             4            5401 Chimney Rock
# ..          ...                           ...
# 103         103                  The Carlton
# 104         104                      Circuit
# 105         105               Avana Eldridge
# 106         106                 Jackson Hill
# 107         107       Veranda at Centerfield
#
#                                   Address  location_lat  location_long  \
# 0            2660 Augusta Dr, Houston, TX     29.739297     -95.482587
# 1        1819 Braeswood Blvd, Houston, TX     29.706742     -95.394089
# 2            1901 Augusta Dr, Houston, TX     29.747442     -95.482511
# 3       200 Dominion Park Dr, Houston, TX     29.975664     -95.424768
# 4       5401 Chimney Rock Rd, Houston, TX     29.723425     -95.475772
# ..                                    ...           ...            ...
# 103        3805 W Alabama St, Houston, TX     29.738168     -95.438803
# 104          2424 Capitol St, Houston, TX     29.751732     -95.350933
# 105       1415 Eldridge Pkwy, Houston, TX     29.758541     -95.625225
# 106      320 Jackson Hill St, Houston, TX     29.764461     -95.401687
# 107   7700 Willow Chase Blvd, Houston, TX     29.966437     -95.547377
#
#                                       location_address  location_lat_rad  \
# 0    2660, Augusta Drive, Houston, Harris County, T...          0.519049
# 1    Braeswood Boulevard, Texas Medical Center, Hou...          0.518480
# 2    1901, Augusta Drive, Houston, Harris County, T...          0.519191
# 3    200, Dominion Park Drive, North Houston Distri...          0.523174
# 4    5401, Chimney Rock Road, Houston, Harris Count...          0.518772
# ..                                                 ...               ...
# 103  3805, West Alabama Street, Highland Village, H...          0.519029
# 104  2424, Capitol Street, Houston, Harris County, ...          0.519266
# 105  1415, Eldridge Parkway, Houston, Harris County...          0.519385
# 106  320, Jackson Hill Street, Houston, Harris Coun...          0.519488
# 107  7700, Willow Chase Boulevard, Houston, Harris ...          0.523013
#
#      location_long_rad
# 0            -1.666486
# 1            -1.664941
# 2            -1.666484
# 3            -1.665476
# 4            -1.666367
# ..                 ...
# 103          -1.665721
# 104          -1.664188
# 105          -1.668975
# 106          -1.665074
# 107          -1.667616
#
# [108 rows x 8 columns]

# %% [markdown]
# The ball tree is constructed using the locations of each Torchy's Tacos. A query is executed against it using the apartment data and a list of distances and indices of each resturant.

# %%
#Constructs ball tree using lat and long from Torchy's dataframe
ball = BallTree(tor_df[['Lat_rad', 'Long_rad']].values, metric='haversine')

#Amount of neighbors to return
k = 2

#Executes a query with the apartment dataframe. Return two arrays
distances, indices = ball.query(apt_df[['location_lat_rad','location_long_rad']].values, k=k)

# %% [markdown]
# Here are the results from the above query. After splitting the arrays, I imported each into separate columns.

# %%
#Indices will show the index of the nearest Torchy's to the apartment
#Need to convert distances to miles
distances, indices
# Out:
# (array([[1.72373084e-04, 7.03454050e-04],
#         [3.65427517e-04, 6.97725136e-04],
#         [3.87406721e-05, 7.75129523e-04],
#         [3.03685566e-03, 3.77881768e-03],
#         [4.65628505e-04, 5.30570820e-04],
#         [5.20394262e-04, 8.40404613e-04],
#         [6.29075423e-04, 1.01018681e-03],
#         [7.33149231e-04, 8.42479774e-04],
#         [1.23818009e-04, 7.64627896e-04],
#         [5.28589267e-04, 6.79075863e-04],
#         [5.45620351e-03, 6.37933223e-03],
#         [6.19665954e-04, 1.08529386e-03],
#         [3.27258176e-04, 4.23449312e-04],
#         [5.89383293e-04, 7.32357609e-04],
#         [4.83832193e-04, 1.03276929e-03],
#         [3.66918637e-04, 9.91557595e-04],
#         [4.67522041e-04, 7.64861092e-04],
#         [6.55955682e-04, 1.08088934e-03],
#         [3.25074517e-04, 4.69820081e-04],
#         [5.77363537e-04, 1.02039129e-03],
#         [2.38422979e-03, 2.64309014e-03],
#         [4.36871225e-04, 6.62599282e-04],
#         [5.63087611e-04, 8.79126849e-04],
#         [8.12365613e-04, 8.54974353e-04],
#         [8.45642574e-04, 1.38974053e-03],
#         [3.79013505e-04, 4.59071067e-04],
#         [1.10597881e-03, 1.53737335e-03],
#         [2.08919791e-03, 3.11046928e-03],
#         [2.16256896e-03, 2.30429053e-03],
#         [6.46082640e-04, 1.55255900e-03],
#         [9.45262351e-04, 1.35825789e-03],
#         [9.87155266e-05, 9.44336399e-04],
#         [2.94974649e-03, 3.69587934e-03],
#         [6.55135409e-04, 7.78693693e-04],
#         [2.03677116e-04, 1.12752892e-03],
#         [4.18401519e-03, 4.39851850e-03],
#         [3.18638179e-03, 3.53982519e-03],
#         [1.75523910e-03, 1.84879567e-03],
#         [3.75159304e-04, 4.63412152e-04],
#         [5.38191725e-03, 6.27512502e-03],
#         [3.01312512e-04, 5.50440833e-04],
#         [1.07085082e-03, 1.50025414e-03],
#         [5.48909025e-04, 6.84158404e-04],
#         [1.45858837e-03, 2.42690239e-03],
#         [9.17735053e-04, 1.34179420e-03],
#         [1.10081676e-03, 1.53030145e-03],
#         [3.98916186e-04, 9.69454110e-04],
#         [2.47039909e-04, 4.91956019e-04],
#         [4.71411756e-04, 6.44028635e-04],
#         [5.91121598e-04, 9.41877006e-04],
#         [4.16272602e-03, 4.36632909e-03],
#         [2.87016407e-03, 3.83116069e-03],
#         [4.37743945e-04, 9.68501020e-04],
#         [5.31400860e-03, 5.49272421e-03],
#         [9.32174961e-04, 9.87569701e-04],
#         [6.78561603e-04, 7.73485997e-04],
#         [1.53262430e-03, 1.60829036e-03],
#         [3.05917415e-04, 5.52622115e-04],
#         [3.84002769e-03, 4.47798576e-03],
#         [5.95404610e-04, 7.45236075e-04],
#         [6.43074750e-04, 1.55124425e-03],
#         [4.24902060e-04, 5.45968741e-04],
#         [6.48622906e-04, 1.53773050e-03],
#         [2.74135361e-04, 3.09005472e-04],
#         [1.96625904e-03, 2.98885966e-03],
#         [2.91710475e-04, 5.28794279e-04],
#         [5.00587619e-04, 6.49396987e-04],
#         [3.01631527e-03, 3.13915762e-03],
#         [1.34130621e-03, 2.13573625e-03],
#         [2.32762788e-04, 7.12098714e-04],
#         [3.70254848e-04, 6.70783928e-04],
#         [4.14989082e-04, 6.16103603e-04],
#         [1.96625904e-03, 2.98885966e-03],
#         [8.50760777e-05, 7.61773328e-04],
#         [1.48376641e-04, 3.57804960e-04],
#         [4.68921681e-04, 5.49552719e-04],
#         [2.11937691e-04, 6.08877693e-04],
#         [4.48703187e-04, 4.77548446e-04],
#         [6.04442355e-04, 7.12514307e-04],
#         [7.89343568e-05, 1.08699551e-03],
#         [5.92636857e-04, 6.77409064e-04],
#         [7.90828905e-04, 1.35157745e-03],
#         [5.44160729e-04, 8.87329378e-04],
#         [5.77905688e-04, 9.02786602e-04],
#         [3.30806829e-03, 3.43834713e-03],
#         [2.94956698e-04, 3.28060472e-04],
#         [4.54004939e-04, 6.82206601e-04],
#         [3.42945590e-04, 7.11535709e-04],
#         [7.03238961e-04, 1.04703826e-03],
#         [1.44911403e-04, 4.33629310e-04],
#         [1.07211690e-03, 1.14845867e-03],
#         [6.63195841e-04, 9.49752679e-04],
#         [1.62494051e-04, 3.33574065e-04],
#         [4.73395857e-04, 5.24594017e-04],
#         [5.87647275e-04, 8.87479859e-04],
#         [6.44550175e-04, 1.54197828e-03],
#         [4.60505530e-04, 7.13138727e-04],
#         [9.40081287e-04, 1.29220081e-03],
#         [3.64473758e-04, 6.63977782e-04],
#         [5.38382934e-04, 8.18582550e-04],
#         [5.11503395e-05, 1.04586583e-03],
#         [7.19304016e-04, 8.67721345e-04],
#         [1.08907222e-03, 1.17077802e-03],
#         [2.88829329e-04, 4.42699428e-04],
#         [9.10953395e-04, 1.14665656e-03],
#         [9.13511412e-04, 1.30680310e-03],
#         [3.78757389e-04, 6.67246103e-04],
#         [3.15184549e-03, 3.59529798e-03]]),
#  array([[4, 3],
#         [2, 0],
#         [4, 3],
#         [1, 5],
#         [4, 3],
#         [0, 2],
#         [5, 4],
#         [1, 4],
#         [4, 3],
#         [2, 3],
#         [1, 0],
#         [6, 5],
#         [0, 2],
#         [3, 4],
#         [1, 0],
#         [1, 0],
#         [0, 2],
#         [1, 4],
#         [2, 3],
#         [4, 5],
#         [1, 0],
#         [4, 3],
#         [2, 3],
#         [6, 5],
#         [6, 5],
#         [3, 4],
#         [6, 5],
#         [1, 0],
#         [6, 5],
#         [5, 4],
#         [1, 4],
#         [6, 5],
#         [1, 5],
#         [6, 4],
#         [6, 5],
#         [2, 0],
#         [5, 1],
#         [0, 2],
#         [3, 4],
#         [1, 0],
#         [4, 3],
#         [6, 5],
#         [1, 0],
#         [6, 5],
#         [1, 4],
#         [6, 5],
#         [4, 6],
#         [3, 0],
#         [0, 2],
#         [1, 0],
#         [2, 0],
#         [1, 5],
#         [6, 4],
#         [2, 0],
#         [5, 6],
#         [6, 4],
#         [6, 5],
#         [3, 4],
#         [1, 5],
#         [6, 4],
#         [5, 4],
#         [6, 5],
#         [5, 4],
#         [3, 2],
#         [1, 0],
#         [4, 3],
#         [1, 0],
#         [1, 0],
#         [5, 4],
#         [0, 2],
#         [0, 1],
#         [0, 1],
#         [1, 0],
#         [4, 3],
#         [0, 2],
#         [2, 0],
#         [3, 2],
#         [4, 3],
#         [6, 5],
#         [1, 0],
#         [1, 0],
#         [6, 5],
#         [2, 0],
#         [0, 1],
#         [1, 0],
#         [3, 0],
#         [0, 1],
#         [0, 1],
#         [2, 0],
#         [0, 2],
#         [6, 5],
#         [0, 2],
#         [2, 3],
#         [4, 3],
#         [2, 0],
#         [5, 4],
#         [0, 2],
#         [6, 5],
#         [1, 0],
#         [0, 2],
#         [1, 0],
#         [2, 3],
#         [6, 5],
#         [3, 0],
#         [0, 2],
#         [6, 5],
#         [0, 1],
#         [5, 1]], dtype=int64))

# %%
ind1, ind2 = zip(*indices)

# %%
dist1, dist2 = zip(*distances)

# %%
apt_df['Torchy_1'] = [tor_df['County'].loc[i] for i in ind1]
apt_df['Torchy_2'] = [tor_df['County'].loc[i] for i in ind2]
apt_df['Tor_Dist_1'] = np.asarray(dist1) * 3958.8 #To get distances to miles
apt_df['Tor_Dist_2'] = np.asarray(dist2) * 3958.8
apt_df['Tor_Lat_1'] = [tor_df['Lat'].loc[i] for i in ind1] 
apt_df['Tor_Long_1'] = [tor_df['Long'].loc[i] for i in ind1] 
apt_df['Tor_Lat_2'] = [tor_df['Lat'].loc[i] for i in ind2]
apt_df['Tor_Long_2'] = [tor_df['Long'].loc[i] for i in ind2]

apt_df
# Out:
#      Unnamed: 0                     Apartment  \
# 0             0                  The Augusta
# 1             1      Lanesborough Apartments
# 2             2     Tuscany Court Apartments
# 3             3  The Trails At Dominion Park
# 4             4            5401 Chimney Rock
# ..          ...                           ...
# 103         103                  The Carlton
# 104         104                      Circuit
# 105         105               Avana Eldridge
# 106         106                 Jackson Hill
# 107         107       Veranda at Centerfield
#
#                                   Address  location_lat  location_long  \
# 0            2660 Augusta Dr, Houston, TX     29.739297     -95.482587
# 1        1819 Braeswood Blvd, Houston, TX     29.706742     -95.394089
# 2            1901 Augusta Dr, Houston, TX     29.747442     -95.482511
# 3       200 Dominion Park Dr, Houston, TX     29.975664     -95.424768
# 4       5401 Chimney Rock Rd, Houston, TX     29.723425     -95.475772
# ..                                    ...           ...            ...
# 103        3805 W Alabama St, Houston, TX     29.738168     -95.438803
# 104          2424 Capitol St, Houston, TX     29.751732     -95.350933
# 105       1415 Eldridge Pkwy, Houston, TX     29.758541     -95.625225
# 106      320 Jackson Hill St, Houston, TX     29.764461     -95.401687
# 107   7700 Willow Chase Blvd, Houston, TX     29.966437     -95.547377
#
#                                       location_address  location_lat_rad  \
# 0    2660, Augusta Drive, Houston, Harris County, T...          0.519049
# 1    Braeswood Boulevard, Texas Medical Center, Hou...          0.518480
# 2    1901, Augusta Drive, Houston, Harris County, T...          0.519191
# 3    200, Dominion Park Drive, North Houston Distri...          0.523174
# 4    5401, Chimney Rock Road, Houston, Harris Count...          0.518772
# ..                                                 ...               ...
# 103  3805, West Alabama Street, Highland Village, H...          0.519029
# 104  2424, Capitol Street, Houston, Harris County, ...          0.519266
# 105  1415, Eldridge Parkway, Houston, Harris County...          0.519385
# 106  320, Jackson Hill Street, Houston, Harris Coun...          0.519488
# 107  7700, Willow Chase Boulevard, Houston, Harris ...          0.523013
#
#      location_long_rad         Torchy_1         Torchy_2  Tor_Dist_1  \
# 0            -1.666486       San Felipe           West U    0.682391
# 1            -1.664941     Rice Village         Shepherd    1.446654
# 2            -1.666484       San Felipe           West U    0.153367
# 3            -1.665476  Houston Heights    Memorial City   12.022304
# 4            -1.666367       San Felipe           West U    1.843330
# ..                 ...              ...              ...         ...
# 103          -1.665721           West U         Shepherd    1.143418
# 104          -1.664188         Shepherd     Rice Village    3.606282
# 105          -1.668975        Westchase    Memorial City    3.616409
# 106          -1.665074         Shepherd  Houston Heights    1.499425
# 107          -1.667616    Memorial City  Houston Heights   12.477526
#
#      Tor_Dist_2  Tor_Lat_1  Tor_Long_1  Tor_Lat_2  Tor_Long_2
# 0      2.784834  29.749067  -95.484253  29.721713  -95.440822
# 1      2.762154  29.716962  -95.415129  29.744123  -95.410407
# 2      3.068583  29.749067  -95.484253  29.721713  -95.440822
# 3     14.959583  29.802667  -95.403260  29.785862  -95.544912
# 4      2.100424  29.749067  -95.484253  29.721713  -95.440822
# ..          ...        ...         ...        ...         ...
# 103    1.752558  29.721713  -95.440822  29.744123  -95.410407
# 104    4.539384  29.744123  -95.410407  29.716962  -95.415129
# 105    5.173372  29.735207  -95.571263  29.785862  -95.544912
# 106    2.641494  29.744123  -95.410407  29.802667  -95.403260
# 107   14.233066  29.785862  -95.544912  29.802667  -95.403260
#
# [108 rows x 16 columns]

# %% [markdown]
# Last, I put each individual column I wanted to export into one dataframe and exported into a CSV file.

# %%
#Create a new df
#Torchy_2, Distance_2, Tor_Lat_2, Tor_Long_2

data = [apt_df['Apartment'], apt_df['location_lat'], 
        apt_df['location_long'], apt_df['Torchy_1'],
       apt_df['Tor_Dist_1'], apt_df['Tor_Lat_1'], apt_df['Tor_Long_1'],
       apt_df['Torchy_2'], apt_df['Tor_Dist_2'],
       apt_df['Tor_Lat_2'], apt_df['Tor_Long_2']]
data_df = pd.concat(data, axis=1)
data_df
# Out:
#                         Apartment  location_lat  location_long  \
# 0                    The Augusta      29.739297     -95.482587
# 1        Lanesborough Apartments      29.706742     -95.394089
# 2       Tuscany Court Apartments      29.747442     -95.482511
# 3    The Trails At Dominion Park      29.975664     -95.424768
# 4              5401 Chimney Rock      29.723425     -95.475772
# ..                            ...           ...            ...
# 103                  The Carlton      29.738168     -95.438803
# 104                      Circuit      29.751732     -95.350933
# 105               Avana Eldridge      29.758541     -95.625225
# 106                 Jackson Hill      29.764461     -95.401687
# 107       Veranda at Centerfield      29.966437     -95.547377
#
#             Torchy_1  Tor_Dist_1  Tor_Lat_1  Tor_Long_1         Torchy_2  \
# 0         San Felipe    0.682391  29.749067  -95.484253           West U
# 1       Rice Village    1.446654  29.716962  -95.415129         Shepherd
# 2         San Felipe    0.153367  29.749067  -95.484253           West U
# 3    Houston Heights   12.022304  29.802667  -95.403260    Memorial City
# 4         San Felipe    1.843330  29.749067  -95.484253           West U
# ..               ...         ...        ...         ...              ...
# 103           West U    1.143418  29.721713  -95.440822         Shepherd
# 104         Shepherd    3.606282  29.744123  -95.410407     Rice Village
# 105        Westchase    3.616409  29.735207  -95.571263    Memorial City
# 106         Shepherd    1.499425  29.744123  -95.410407  Houston Heights
# 107    Memorial City   12.477526  29.785862  -95.544912  Houston Heights
#
#      Tor_Dist_2  Tor_Lat_2  Tor_Long_2
# 0      2.784834  29.721713  -95.440822
# 1      2.762154  29.744123  -95.410407
# 2      3.068583  29.721713  -95.440822
# 3     14.959583  29.785862  -95.544912
# 4      2.100424  29.721713  -95.440822
# ..          ...        ...         ...
# 103    1.752558  29.744123  -95.410407
# 104    4.539384  29.716962  -95.415129
# 105    5.173372  29.785862  -95.544912
# 106    2.641494  29.802667  -95.403260
# 107   14.233066  29.802667  -95.403260
#
# [108 rows x 11 columns]

# %%
data_df.to_csv('Nearest Torchys.csv')

# %% [markdown]
# My next step is to visualize how close the apartments are from a Torchy's Tacos location.
